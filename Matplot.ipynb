# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

circle1 = plt.Circle((0, 0), 2, color='r')
# now make a circle with no fill, which is good for hi-lighting key results
circle2 = plt.Circle((5, 5), 0.5, color='b', fill=False)
circle3 = plt.Circle((10, 10), 2, color='g', clip_on=False)

ax = plt.gca()
ax.cla() # clear things for fresh plot

# change default range so that new circles will work
ax.set_xlim((0, 10))
ax.set_ylim((0, 10))
# some data
ax.plot(range(11), 'o', color='black')
# key data point that we are encircling
ax.plot((5), (5), 'o', color='y')

ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)
#fig.savefig('plotcircles2.png')

plt.show()

# %%
'''
This code was downloaded from the official matplotlib.org website.
It is one of the examples freely available on this website.
It's name at the time of printing was: surface3d_demo.py'''

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
        linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

circle1 = plt.Circle((0, 0), 2, color='r')
# now make a circle with no fill, which is good for hi-lighting key results
circle2 = plt.Circle((5, 5), 0.5, color='b', fill=False)
circle3 = plt.Circle((10, 10), 2, color='g', clip_on=False)

ax = plt.gca()
ax.cla() # clear things for fresh plot

# change default range so that new circles will work
ax.set_xlim((0, 10))
ax.set_ylim((0, 10))
# some data
ax.plot(range(11), 'o', color='black')
# key data point that we are encircling
ax.plot((5), (5), 'o', color='y')

ax.add_artist(circle1)
#ax.add_artist(circle2)
#ax.add_artist(circle3)
fig.savefig('plotcircles2.png')

plt.show()

# %%
'''
Created on Jul 20, 2015
@author: Burkhard
'''
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import tkinter as tk
from tkinter import *
import numpy as np


#--------------------------------------------------------------               
fig = Figure(figsize=(12, 8), facecolor='grey')
#--------------------------------------------------------------     
axis = fig.add_subplot(211)     # 2 rows, 1 column, Top graph       
#--------------------------------------------------------------
xValues = np.arange(0, 30, 0.1);
yValues0 =  np.sqrt(xValues)
axis.plot(xValues, yValues0)

axis.set_xlabel('Horizontal Label')
axis.set_ylabel('Vertical Label')

axis.grid(linestyle='-')        # solid grid lines
#--------------------------------------------------------------
axis1 = fig.add_subplot(212)    # 2 rows, 1 column, Bottom graph       
#--------------------------------------------------------------
xValues1 = np.arange(0, 30, 0.1);
yValues1 = np.sin(xValues1)
axis1.plot(xValues1, yValues1)
axis1.grid()                    # default line style 
#-------------------------------------------------------------- 
def _destroyWindow():
    root.quit()
    root.destroy() 
#--------------------------------------------------------------
root = tk.Tk() 
root.title("GRAPHIC INTERFACE FOR NOOB")
root.withdraw()
ttk.Label(root, text = "TESTING FUTURE PROOF TECHNOLOGY", justify = RIGHT).pack(side=tk.TOP, fill=tk.BOTH, expand=0)
root.protocol('WM_DELETE_WINDOW', _destroyWindow)   
#--------------------------------------------------------------  
canvas = FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.pack(side=tk.TOP, fill=tk.BOTH, expand=1)         
#--------------------------------------------------------------  
root.update()
root.deiconify()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f597e2b00cda> in <module>()
#      38 root.title("GRAPHIC INTERFACE FOR NOOB")
#      39 root.withdraw()
# ---> 40 ttk.Label(root, text = "TESTING FUTURE PROOF TECHNOLOGY", justify = RIGHT).pack(side=tk.TOP, fill=tk.BOTH, expand=0)
#      41 root.protocol('WM_DELETE_WINDOW', _destroyWindow)
#      42 #--------------------------------------------------------------
#
# NameError: name 'ttk' is not defined

# %%
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import tkinter as tk
from tkinter import *
import numpy as np


#--------------------------------------------------------------               
fig = Figure(figsize=(12, 8), facecolor='grey')
#--------------------------------------------------------------     
axis = fig.add_subplot(111)     # 2 rows, 1 column, Top graph       
#--------------------------------------------------------------
a = 0
b = 0
c = 0
d = 0
e = 0
xValues = np.arange(0, 0, 0.1);

yValues0 =  np.array(a*(xValues**4)+b*(xValues**3)+c*(xValues**2)+d*(xValues) + e )

axis.plot(xValues, yValues0)

axis.set_xlabel('Horizontal Label')
axis.set_ylabel('Vertical Label')

axis.grid(linestyle='-')        # solid grid lines
#--------------------------------------------------------------
def plot() :
    a = myentry2.get()
    b = myentry3.get()
    c = myentry4.get()
    d = myentry5.get()
    e = myentry6.get()
    mini = myentry8.get()
    maxi = myentry9.get()
    try:
        a = float(a)
    except ValueError:
        myentry2.insert(END, 'Bad Input')
    try:
        b = float(b)
    except ValueError:
        myentry3.insert(END, 'Bad Input')
    try:
        c = float(c)
    except ValueError:
        myentry4.insert(END, 'Bad Input')
    try:
        d = float(d)
    except ValueError:
        myentry5.insert(END, 'Bad Input')
    try:
        e = float(e)
    except ValueError:
        myentry6.insert(END, 'Bad Input')
    try:
        mini = float(mini)
    except ValueError:
        myentry3.insert(END, 'Bad Input')
    try:
        maxi = float(maxi)
    except ValueError:
        myentry3.insert(END, 'Bad Input')   
        
    xValues = np.arange(mini, maxi, 0.1);
    yValues0 =  np.array(a*(xValues**4)+b*(xValues**3)+c*(xValues**2)+d*(xValues)+e )
    
    axis.plot(xValues, yValues0)
    axis.set_xlabel('Horizontal Label')
    axis.set_ylabel('Vertical Label') 
    canvas = FigureCanvasTkAgg(fig, master=root)
    canvas._tkcanvas.grid(columnspan = 30, row = 2, column = 0)
    axis.grid(linestyle='-')        # solid grid lines

def _destroyWindow():
    root.quit()
    root.destroy() 
def clear():
    axis.clear()
    myentry2.delete(0,END)
    myentry3.delete(0,END)
    myentry4.delete(0,END)
    myentry5.delete(0,END)
    myentry6.delete(0,END)
    myentry8.delete(0,END)
    myentry9.delete(0,END)
    myentry2.insert(END,'0')
    myentry3.insert(END,'0')
    myentry4.insert(END,'0')
    myentry5.insert(END,'0')
    myentry6.insert(END,'0')
    myentry8.insert(END,'0')
    myentry9.insert(END,'0')
    
    a = myentry2.get()
    b = myentry3.get()
    c = myentry4.get()
    d = myentry5.get()
    e = myentry6.get()
    mini = myentry8.get()
    maxi = myentry9.get()
    try:
        a = float(a)
    except ValueError:
        myentry2.insert(END, 'Bad Input')
    try:
        b = float(b)
    except ValueError:
        myentry3.insert(END, 'Bad Input')
    try:
        c = float(c)
    except ValueError:
        myentry4.insert(END, 'Bad Input')
    try:
        d = float(d)
    except ValueError:
        myentry5.insert(END, 'Bad Input')
    try:
        e = float(e)
    except ValueError:
        myentry6.insert(END, 'Bad Input')
    try:
        mini = float(mini)
    except ValueError:
        myentry3.insert(END, 'Bad Input')
    try:
        maxi = float(maxi)
    except ValueError:
        myentry3.insert(END, 'Bad Input')   
        
    xValues = np.arange(mini, maxi, 0.1);
    yValues0 =  np.array(a*(xValues**4)+b*(xValues**3)+c*(xValues**2)+d*(xValues)+e )
    
    axis.plot(xValues, yValues0)
    axis.set_xlabel('Horizontal Label')
    axis.set_ylabel('Vertical Label') 
    canvas = FigureCanvasTkAgg(fig, master=root)
    canvas._tkcanvas.grid(columnspan = 30, row = 2, column = 0)
    axis.grid(linestyle='-')        # solid grid lines
#--------------------------------------------------------------
root = tk.Tk() 
root.title("GRAPHIC INTERFACE FOR NOOB")
Label1 = tk.Label(root, text = 'Input Equation Here : Ax^4 + Bx^3 + Cx^2 + Dx + E', width = 100)
Label1.grid( row = 3, columnspan = 30)

Label2 = tk.Label(root, justify=LEFT, text = 'A :')
Label2.grid(row = 4, column = 0)
myentry2 = tk.Entry(root, justify=RIGHT)
myentry2.grid(row = 4, column = 1)
myentry2.insert(END,'0')

Label3 = tk.Label(root, justify=LEFT, text = 'B :')
Label3.grid(row = 4, column = 2)
myentry3 = tk.Entry(root, justify=RIGHT)
myentry3.grid(row = 4, column = 3)
myentry3.insert(END,'0')

Label4 = tk.Label(root, justify=LEFT, text = 'C :')
Label4.grid(row = 4, column = 4)
myentry4 = tk.Entry(root, justify=RIGHT)
myentry4.grid(row = 4, column = 5)
myentry4.insert(END,'0')

Label5 = tk.Label(root, justify=LEFT, text = 'D :')
Label5.grid(row = 4, column = 6)
myentry5 = tk.Entry(root, justify=RIGHT)
myentry5.grid(row = 4, column = 7)
myentry5.insert(END,'0')

Label6 = tk.Label(root, justify=LEFT, text = 'E :')
Label6.grid(row = 4, column = 8)
myentry6 = tk.Entry(root, justify=RIGHT)
myentry6.grid(row = 4, column = 9)
myentry6.insert(END,'0')

Label8 = tk.Label(root, justify=LEFT, text = 'Min :')
Label8.grid(row = 5, column = 0)
myentry8 = tk.Entry(root, justify=RIGHT)
myentry8.grid(row = 5, column = 1)
myentry8.insert(END,'0')

Label9 = tk.Label(root, justify=LEFT, text = 'Max :')
Label9.grid(row = 5, column = 2)
myentry9 = tk.Entry(root, justify=RIGHT)
myentry9.grid(row = 5, column = 3)
myentry9.insert(END,'0')

but1 = tk.Button(root, text = 'CLEAR', command = clear).grid(column = 9, row =5, columnspan = 1)
but2 = tk.Button(root, text = 'PLOT', command = plot).grid(column = 10, row =5, columnspan = 1)

root.withdraw()
root.protocol('WM_DELETE_WINDOW', _destroyWindow)   
root.resizable(0,0)
#--------------------------------------------------------------  
canvas = FigureCanvasTkAgg(fig, master=root)
canvas._tkcanvas.grid(columnspan = 30, row = 2, column = 0)      
#--------------------------------------------------------------  
root.update()
root.deiconify()
root.mainloop()

# %%
'''
This code was downloaded from the official matplotlib.org website.
It is one of the examples freely available on this website.
It's name at the time of printing was: surface3d_demo.py'''

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
W = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2 + W**2)
Z = R
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
        linewidth=0, antialiased=False)
ax.set_zlim(-1.01, 1.01)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

u = np.linspace(0, 2 * np.pi, 20)
v = np.linspace(0, np.pi, 7)

x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))
ax.plot_surface(x, y, z, rstride=1, cstride=1, color='w', shade=0)

plt.show()
