# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'Fusion.ui'
#
# Created by: PyQt5 UI code generator 5.5.1
#
# WARNING! All changes made in this file will be lost!
import sys
from PyQt5 import QtCore, QtGui, QtWidgets

class Ui_MainWindow(object):
    def setupUi(self, MainWindow):
        MainWindow.setObjectName("MainWindow")
        MainWindow.resize(1200, 800)
        MainWindow.setMinimumSize(QtCore.QSize(1200, 800))
        MainWindow.setMaximumSize(QtCore.QSize(1200, 800))
        self.centralwidget = QtWidgets.QWidget(MainWindow)
        self.centralwidget.setObjectName("centralwidget")
        self.tabWidget = QtWidgets.QTabWidget(self.centralwidget)
        self.tabWidget.setGeometry(QtCore.QRect(10, 10, 1181, 751))
        
        self.tabWidget.setObjectName("tabWidget")

        self.Calculator = QtWidgets.QWidget()
        self.Calculator.setObjectName("Calculator")
        self.lcdNumber = QtWidgets.QLCDNumber(self.Calculator)
        self.lcdNumber.setGeometry(QtCore.QRect(10, 50, 1151, 101))
        self.lcdNumber.setObjectName("lcdNumber")
        self.pushButton = QtWidgets.QPushButton(self.Calculator)
        self.pushButton.setGeometry(QtCore.QRect(330, 290, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton.setFont(font)
        self.pushButton.setObjectName("pushButton")
        
        self.pushButton_2 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_2.setGeometry(QtCore.QRect(410, 290, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_2.setFont(font)
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_3 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_3.setGeometry(QtCore.QRect(490, 290, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_3.setFont(font)
        self.pushButton_3.setObjectName("pushButton_3")
        self.pushButton_4 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_4.setGeometry(QtCore.QRect(570, 290, 151, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_4.setFont(font)
        self.pushButton_4.setObjectName("pushButton_4")
        self.pushButton_6 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_6.setGeometry(QtCore.QRect(410, 350, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_6.setFont(font)
        self.pushButton_6.setObjectName("pushButton_6")
        self.pushButton_7 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_7.setGeometry(QtCore.QRect(570, 350, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_7.setFont(font)
        self.pushButton_7.setObjectName("pushButton_7")
        self.pushButton_8 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_8.setGeometry(QtCore.QRect(650, 350, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_8.setFont(font)
        self.pushButton_8.setObjectName("pushButton_8")
        self.pushButton_9 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_9.setGeometry(QtCore.QRect(490, 350, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_9.setFont(font)
        self.pushButton_9.setObjectName("pushButton_9")
        self.pushButton_10 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_10.setGeometry(QtCore.QRect(330, 350, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_10.setFont(font)
        self.pushButton_10.setObjectName("pushButton_10")
        self.pushButton_11 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_11.setGeometry(QtCore.QRect(570, 410, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_11.setFont(font)
        self.pushButton_11.setObjectName("pushButton_11")
        self.pushButton_12 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_12.setGeometry(QtCore.QRect(490, 410, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_12.setFont(font)
        self.pushButton_12.setObjectName("pushButton_12")
        self.pushButton_13 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_13.setGeometry(QtCore.QRect(650, 410, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_13.setFont(font)
        self.pushButton_13.setObjectName("pushButton_13")
        self.pushButton_14 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_14.setGeometry(QtCore.QRect(330, 410, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_14.setFont(font)
        self.pushButton_14.setObjectName("pushButton_14")
        self.pushButton_15 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_15.setGeometry(QtCore.QRect(410, 410, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_15.setFont(font)
        self.pushButton_15.setObjectName("pushButton_15")
        self.pushButton_16 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_16.setGeometry(QtCore.QRect(330, 470, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_16.setFont(font)
        self.pushButton_16.setObjectName("pushButton_16")
        self.pushButton_17 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_17.setGeometry(QtCore.QRect(410, 470, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_17.setFont(font)
        self.pushButton_17.setObjectName("pushButton_17")
        self.pushButton_18 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_18.setGeometry(QtCore.QRect(570, 470, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_18.setFont(font)
        self.pushButton_18.setObjectName("pushButton_18")
        self.pushButton_19 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_19.setGeometry(QtCore.QRect(650, 470, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_19.setFont(font)
        self.pushButton_19.setObjectName("pushButton_19")
        self.pushButton_21 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_21.setGeometry(QtCore.QRect(730, 290, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_21.setFont(font)
        self.pushButton_21.setObjectName("pushButton_21")
        self.pushButton_22 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_22.setGeometry(QtCore.QRect(730, 350, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_22.setFont(font)
        self.pushButton_22.setObjectName("pushButton_22")
        self.pushButton_23 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_23.setGeometry(QtCore.QRect(730, 410, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_23.setFont(font)
        self.pushButton_23.setObjectName("pushButton_23")
        self.pushButton_24 = QtWidgets.QPushButton(self.Calculator)
        self.pushButton_24.setGeometry(QtCore.QRect(730, 470, 75, 51))
        font = QtGui.QFont()
        font.setPointSize(23)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_24.setFont(font)
        self.pushButton_24.setObjectName("pushButton_24")
        self.line_3 = QtWidgets.QFrame(self.Calculator)
        self.line_3.setGeometry(QtCore.QRect(0, 210, 1181, 20))
        self.line_3.setFrameShape(QtWidgets.QFrame.HLine)
        self.line_3.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line_3.setObjectName("line_3")
        self.line_4 = QtWidgets.QFrame(self.Calculator)
        self.line_4.setGeometry(QtCore.QRect(0, 590, 1181, 20))
        self.line_4.setFrameShape(QtWidgets.QFrame.HLine)
        self.line_4.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line_4.setObjectName("line_4")
        self.line_5 = QtWidgets.QFrame(self.Calculator)
        self.line_5.setGeometry(QtCore.QRect(203, 220, 20, 381))
        self.line_5.setFrameShape(QtWidgets.QFrame.VLine)
        self.line_5.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line_5.setObjectName("line_5")
        self.line_6 = QtWidgets.QFrame(self.Calculator)
        self.line_6.setGeometry(QtCore.QRect(910, 220, 16, 381))
        self.line_6.setFrameShape(QtWidgets.QFrame.VLine)
        self.line_6.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line_6.setObjectName("line_6")
        self.tabWidget.addTab(self.Calculator, "")
        self.Converter = QtWidgets.QWidget()
        self.Converter.setObjectName("Converter")
        self.lineEdit = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit.setGeometry(QtCore.QRect(10, 40, 341, 31))
        self.lineEdit.setObjectName("lineEdit")
        self.label = QtWidgets.QLabel(self.Converter)
        self.label.setGeometry(QtCore.QRect(20, 10, 311, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label.setFont(font)
        self.label.setAlignment(QtCore.Qt.AlignCenter)
        self.label.setObjectName("label")
        self.line = QtWidgets.QFrame(self.Converter)
        self.line.setGeometry(QtCore.QRect(570, 0, 20, 721))
        self.line.setFrameShape(QtWidgets.QFrame.VLine)
        self.line.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line.setObjectName("line")
        self.label_2 = QtWidgets.QLabel(self.Converter)
        self.label_2.setGeometry(QtCore.QRect(390, 10, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_2.setFont(font)
        self.label_2.setAlignment(QtCore.Qt.AlignCenter)
        self.label_2.setObjectName("label_2")
        self.comboBox = QtWidgets.QComboBox(self.Converter)
        self.comboBox.setGeometry(QtCore.QRect(390, 40, 69, 31))
        self.comboBox.setObjectName("comboBox")
        self.lineEdit_2 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_2.setGeometry(QtCore.QRect(10, 80, 341, 31))
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.line_2 = QtWidgets.QFrame(self.Converter)
        self.line_2.setGeometry(QtCore.QRect(0, 330, 1171, 21))
        self.line_2.setFrameShape(QtWidgets.QFrame.HLine)
        self.line_2.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line_2.setObjectName("line_2")
        self.lineEdit_3 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_3.setGeometry(QtCore.QRect(10, 120, 341, 31))
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.lineEdit_4 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_4.setGeometry(QtCore.QRect(10, 160, 341, 31))
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.label_3 = QtWidgets.QLabel(self.Converter)
        self.label_3.setGeometry(QtCore.QRect(390, 90, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setUnderline(False)
        font.setWeight(75)
        self.label_3.setFont(font)
        self.label_3.setTextFormat(QtCore.Qt.AutoText)
        self.label_3.setAlignment(QtCore.Qt.AlignCenter)
        self.label_3.setWordWrap(False)
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(self.Converter)
        self.label_4.setGeometry(QtCore.QRect(390, 130, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_4.setFont(font)
        self.label_4.setAlignment(QtCore.Qt.AlignCenter)
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(self.Converter)
        self.label_5.setGeometry(QtCore.QRect(390, 170, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_5.setFont(font)
        self.label_5.setAlignment(QtCore.Qt.AlignCenter)
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(self.Converter)
        self.label_6.setGeometry(QtCore.QRect(970, 90, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setUnderline(False)
        font.setWeight(75)
        self.label_6.setFont(font)
        self.label_6.setTextFormat(QtCore.Qt.AutoText)
        self.label_6.setAlignment(QtCore.Qt.AlignCenter)
        self.label_6.setWordWrap(False)
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(self.Converter)
        self.label_7.setGeometry(QtCore.QRect(970, 130, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_7.setFont(font)
        self.label_7.setAlignment(QtCore.Qt.AlignCenter)
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(self.Converter)
        self.label_8.setGeometry(QtCore.QRect(970, 170, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_8.setFont(font)
        self.label_8.setAlignment(QtCore.Qt.AlignCenter)
        self.label_8.setObjectName("label_8")
        self.comboBox_2 = QtWidgets.QComboBox(self.Converter)
        self.comboBox_2.setGeometry(QtCore.QRect(970, 40, 69, 31))
        self.comboBox_2.setObjectName("comboBox_2")
        self.label_9 = QtWidgets.QLabel(self.Converter)
        self.label_9.setGeometry(QtCore.QRect(970, 10, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_9.setFont(font)
        self.label_9.setAlignment(QtCore.Qt.AlignCenter)
        self.label_9.setObjectName("label_9")
        self.lineEdit_5 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_5.setGeometry(QtCore.QRect(590, 160, 341, 31))
        self.lineEdit_5.setObjectName("lineEdit_5")
        self.lineEdit_6 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_6.setGeometry(QtCore.QRect(590, 40, 341, 31))
        self.lineEdit_6.setObjectName("lineEdit_6")
        self.label_10 = QtWidgets.QLabel(self.Converter)
        self.label_10.setGeometry(QtCore.QRect(600, 10, 311, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_10.setFont(font)
        self.label_10.setAlignment(QtCore.Qt.AlignCenter)
        self.label_10.setObjectName("label_10")
        self.lineEdit_7 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_7.setGeometry(QtCore.QRect(590, 80, 341, 31))
        self.lineEdit_7.setObjectName("lineEdit_7")
        self.lineEdit_8 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_8.setGeometry(QtCore.QRect(590, 120, 341, 31))
        self.lineEdit_8.setObjectName("lineEdit_8")
        self.lineEdit_9 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_9.setGeometry(QtCore.QRect(10, 470, 341, 31))
        self.lineEdit_9.setObjectName("lineEdit_9")
        self.label_11 = QtWidgets.QLabel(self.Converter)
        self.label_11.setGeometry(QtCore.QRect(390, 440, 71, 21))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setUnderline(False)
        font.setWeight(75)
        self.label_11.setFont(font)
        self.label_11.setTextFormat(QtCore.Qt.AutoText)
        self.label_11.setAlignment(QtCore.Qt.AlignCenter)
        self.label_11.setWordWrap(False)
        self.label_11.setObjectName("label_11")
        self.lineEdit_10 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_10.setGeometry(QtCore.QRect(10, 510, 341, 31))
        self.lineEdit_10.setObjectName("lineEdit_10")
        self.comboBox_3 = QtWidgets.QComboBox(self.Converter)
        self.comboBox_3.setGeometry(QtCore.QRect(390, 390, 69, 31))
        self.comboBox_3.setObjectName("comboBox_3")
        self.lineEdit_11 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_11.setGeometry(QtCore.QRect(10, 430, 341, 31))
        self.lineEdit_11.setObjectName("lineEdit_11")
        self.label_12 = QtWidgets.QLabel(self.Converter)
        self.label_12.setGeometry(QtCore.QRect(390, 480, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_12.setFont(font)
        self.label_12.setAlignment(QtCore.Qt.AlignCenter)
        self.label_12.setObjectName("label_12")
        self.lineEdit_12 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_12.setGeometry(QtCore.QRect(10, 390, 341, 31))
        self.lineEdit_12.setObjectName("lineEdit_12")
        self.label_13 = QtWidgets.QLabel(self.Converter)
        self.label_13.setGeometry(QtCore.QRect(390, 510, 71, 21))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_13.setFont(font)
        self.label_13.setAlignment(QtCore.Qt.AlignCenter)
        self.label_13.setObjectName("label_13")
        self.label_14 = QtWidgets.QLabel(self.Converter)
        self.label_14.setGeometry(QtCore.QRect(20, 360, 311, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_14.setFont(font)
        self.label_14.setAlignment(QtCore.Qt.AlignCenter)
        self.label_14.setObjectName("label_14")
        self.label_15 = QtWidgets.QLabel(self.Converter)
        self.label_15.setGeometry(QtCore.QRect(390, 360, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_15.setFont(font)
        self.label_15.setAlignment(QtCore.Qt.AlignCenter)
        self.label_15.setObjectName("label_15")
        self.label_16 = QtWidgets.QLabel(self.Converter)
        self.label_16.setGeometry(QtCore.QRect(980, 440, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setUnderline(False)
        font.setWeight(75)
        self.label_16.setFont(font)
        self.label_16.setTextFormat(QtCore.Qt.AutoText)
        self.label_16.setAlignment(QtCore.Qt.AlignCenter)
        self.label_16.setWordWrap(False)
        self.label_16.setObjectName("label_16")
        self.lineEdit_13 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_13.setGeometry(QtCore.QRect(600, 390, 341, 31))
        self.lineEdit_13.setObjectName("lineEdit_13")
        self.label_17 = QtWidgets.QLabel(self.Converter)
        self.label_17.setGeometry(QtCore.QRect(980, 360, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_17.setFont(font)
        self.label_17.setAlignment(QtCore.Qt.AlignCenter)
        self.label_17.setObjectName("label_17")
        self.lineEdit_14 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_14.setGeometry(QtCore.QRect(600, 510, 341, 31))
        self.lineEdit_14.setObjectName("lineEdit_14")
        self.comboBox_4 = QtWidgets.QComboBox(self.Converter)
        self.comboBox_4.setGeometry(QtCore.QRect(980, 390, 69, 31))
        self.comboBox_4.setObjectName("comboBox_4")
        self.label_18 = QtWidgets.QLabel(self.Converter)
        self.label_18.setGeometry(QtCore.QRect(980, 520, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_18.setFont(font)
        self.label_18.setAlignment(QtCore.Qt.AlignCenter)
        self.label_18.setObjectName("label_18")
        self.label_19 = QtWidgets.QLabel(self.Converter)
        self.label_19.setGeometry(QtCore.QRect(610, 360, 311, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_19.setFont(font)
        self.label_19.setAlignment(QtCore.Qt.AlignCenter)
        self.label_19.setObjectName("label_19")
        self.lineEdit_15 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_15.setGeometry(QtCore.QRect(600, 470, 341, 31))
        self.lineEdit_15.setObjectName("lineEdit_15")
        self.label_20 = QtWidgets.QLabel(self.Converter)
        self.label_20.setGeometry(QtCore.QRect(980, 480, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_20.setFont(font)
        self.label_20.setAlignment(QtCore.Qt.AlignCenter)
        self.label_20.setObjectName("label_20")
        self.lineEdit_16 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_16.setGeometry(QtCore.QRect(600, 430, 341, 31))
        self.lineEdit_16.setObjectName("lineEdit_16")
        self.lineEdit_17 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_17.setGeometry(QtCore.QRect(600, 550, 341, 31))
        self.lineEdit_17.setObjectName("lineEdit_17")
        self.label_21 = QtWidgets.QLabel(self.Converter)
        self.label_21.setGeometry(QtCore.QRect(980, 560, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_21.setFont(font)
        self.label_21.setAlignment(QtCore.Qt.AlignCenter)
        self.label_21.setObjectName("label_21")
        self.lineEdit_18 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_18.setGeometry(QtCore.QRect(10, 550, 341, 31))
        self.lineEdit_18.setObjectName("lineEdit_18")
        self.label_22 = QtWidgets.QLabel(self.Converter)
        self.label_22.setGeometry(QtCore.QRect(390, 550, 71, 21))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_22.setFont(font)
        self.label_22.setAlignment(QtCore.Qt.AlignCenter)
        self.label_22.setObjectName("label_22")
        self.lineEdit_19 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_19.setGeometry(QtCore.QRect(590, 200, 341, 31))
        self.lineEdit_19.setText("")
        self.lineEdit_19.setObjectName("lineEdit_19")
        self.label_23 = QtWidgets.QLabel(self.Converter)
        self.label_23.setGeometry(QtCore.QRect(970, 210, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_23.setFont(font)
        self.label_23.setAlignment(QtCore.Qt.AlignCenter)
        self.label_23.setObjectName("label_23")
        self.lineEdit_20 = QtWidgets.QLineEdit(self.Converter)
        self.lineEdit_20.setGeometry(QtCore.QRect(10, 200, 341, 31))
        self.lineEdit_20.setObjectName("lineEdit_20")
        self.label_24 = QtWidgets.QLabel(self.Converter)
        self.label_24.setGeometry(QtCore.QRect(390, 210, 71, 16))
        font = QtGui.QFont()
        font.setPointSize(11)
        font.setBold(True)
        font.setWeight(75)
        self.label_24.setFont(font)
        self.label_24.setAlignment(QtCore.Qt.AlignCenter)
        self.label_24.setObjectName("label_24")
        self.pushButton_5 = QtWidgets.QPushButton(self.Converter)
        self.pushButton_5.setGeometry(QtCore.QRect(490, 120, 75, 61))
        font = QtGui.QFont()
        font.setPointSize(15)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_5.setFont(font)
        self.pushButton_5.setObjectName("pushButton_5")
        self.pushButton_20 = QtWidgets.QPushButton(self.Converter)
        self.pushButton_20.setGeometry(QtCore.QRect(1080, 110, 75, 61))
        font = QtGui.QFont()
        font.setPointSize(15)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_20.setFont(font)
        self.pushButton_20.setObjectName("pushButton_20")
        self.pushButton_25 = QtWidgets.QPushButton(self.Converter)
        self.pushButton_25.setGeometry(QtCore.QRect(490, 460, 75, 61))
        font = QtGui.QFont()
        font.setPointSize(15)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_25.setFont(font)
        self.pushButton_25.setObjectName("pushButton_25")
        self.pushButton_26 = QtWidgets.QPushButton(self.Converter)
        self.pushButton_26.setGeometry(QtCore.QRect(1080, 450, 75, 61))
        font = QtGui.QFont()
        font.setPointSize(15)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_26.setFont(font)
        self.pushButton_26.setObjectName("pushButton_26")
        self.tabWidget.addTab(self.Converter, "")
        self.Counter = QtWidgets.QWidget()
        self.Counter.setObjectName("Counter")
        self.label_25 = QtWidgets.QLabel(self.Counter)
        self.label_25.setGeometry(QtCore.QRect(350, 40, 611, 51))
        font = QtGui.QFont()
        font.setPointSize(19)
        self.label_25.setFont(font)
        self.label_25.setObjectName("label_25")
        self.lineEdit_21 = QtWidgets.QLineEdit(self.Counter)
        self.lineEdit_21.setGeometry(QtCore.QRect(440, 110, 241, 71))
        self.lineEdit_21.setObjectName("lineEdit_21")
        self.label_26 = QtWidgets.QLabel(self.Counter)
        self.label_26.setGeometry(QtCore.QRect(700, 120, 91, 51))
        font = QtGui.QFont()
        font.setPointSize(19)
        self.label_26.setFont(font)
        self.label_26.setObjectName("label_26")
        self.label_27 = QtWidgets.QLabel(self.Counter)
        self.label_27.setGeometry(QtCore.QRect(440, 390, 281, 111))
        font = QtGui.QFont()
        font.setPointSize(50)
        font.setBold(True)
        font.setWeight(75)
        self.label_27.setFont(font)
        self.label_27.setAlignment(QtCore.Qt.AlignCenter)
        self.label_27.setObjectName("label_27")
        self.label_28 = QtWidgets.QLabel(self.Counter)
        self.label_28.setGeometry(QtCore.QRect(430, 560, 281, 111))
        font = QtGui.QFont()
        font.setPointSize(50)
        font.setBold(True)
        font.setWeight(75)
        self.label_28.setFont(font)
        self.label_28.setAlignment(QtCore.Qt.AlignCenter)
        self.label_28.setObjectName("label_28")
        self.line_7 = QtWidgets.QFrame(self.Counter)
        self.line_7.setGeometry(QtCore.QRect(223, 0, 20, 721))
        self.line_7.setFrameShape(QtWidgets.QFrame.VLine)
        self.line_7.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line_7.setObjectName("line_7")
        self.line_8 = QtWidgets.QFrame(self.Counter)
        self.line_8.setGeometry(QtCore.QRect(940, 0, 20, 721))
        self.line_8.setFrameShape(QtWidgets.QFrame.VLine)
        self.line_8.setFrameShadow(QtWidgets.QFrame.Sunken)
        self.line_8.setObjectName("line_8")
        self.pushButton_27 = QtWidgets.QPushButton(self.Counter)
        self.pushButton_27.setGeometry(QtCore.QRect(470, 230, 201, 81))
        font = QtGui.QFont()
        font.setPointSize(25)
        font.setBold(True)
        font.setWeight(75)
        self.pushButton_27.setFont(font)
        self.pushButton_27.setObjectName("pushButton_27")
        self.tabWidget.addTab(self.Counter, "")
        MainWindow.setCentralWidget(self.centralwidget)
        self.menubar = QtWidgets.QMenuBar(MainWindow)
        self.menubar.setGeometry(QtCore.QRect(0, 0, 1200, 21))
        self.menubar.setObjectName("menubar")
        MainWindow.setMenuBar(self.menubar)
        self.statusbar = QtWidgets.QStatusBar(MainWindow)
        self.statusbar.setObjectName("statusbar")
        MainWindow.setStatusBar(self.statusbar)

        self.retranslateUi(MainWindow)
        self.tabWidget.setCurrentIndex(0)
        QtCore.QMetaObject.connectSlotsByName(MainWindow)

    def retranslateUi(self, MainWindow):
        _translate = QtCore.QCoreApplication.translate
        MainWindow.setWindowTitle(_translate("MainWindow", "MainWindow"))
        self.pushButton.setText(_translate("MainWindow", "1"))
        self.pushButton_2.setText(_translate("MainWindow", "2"))
        self.pushButton_3.setText(_translate("MainWindow", "3"))
        self.pushButton_4.setText(_translate("MainWindow", "="))
        self.pushButton_6.setText(_translate("MainWindow", "5"))
        self.pushButton_7.setText(_translate("MainWindow", "("))
        self.pushButton_8.setText(_translate("MainWindow", ")"))
        self.pushButton_9.setText(_translate("MainWindow", "6"))
        self.pushButton_10.setText(_translate("MainWindow", "4"))
        self.pushButton_11.setText(_translate("MainWindow", "+"))
        self.pushButton_12.setText(_translate("MainWindow", "9"))
        self.pushButton_13.setText(_translate("MainWindow", "-"))
        self.pushButton_14.setText(_translate("MainWindow", "7"))
        self.pushButton_15.setText(_translate("MainWindow", "8"))
        self.pushButton_16.setText(_translate("MainWindow", "0"))
        self.pushButton_17.setText(_translate("MainWindow", "."))
        self.pushButton_18.setText(_translate("MainWindow", "*"))
        self.pushButton_19.setText(_translate("MainWindow", "/"))
        self.pushButton_21.setText(_translate("MainWindow", "C"))
        self.pushButton_22.setText(_translate("MainWindow", "^"))
        self.pushButton_23.setText(_translate("MainWindow", "X^2"))
        self.pushButton_24.setText(_translate("MainWindow", "X^3"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.Calculator), _translate("MainWindow", "Calculator"))
        self.label.setText(_translate("MainWindow", "VOLUME"))
        self.label_2.setText(_translate("MainWindow", "Unit"))
        self.label_3.setText(_translate("MainWindow", "<html><head/><body><p>M<span style=\" vertical-align:super;\">3</span></p></body></html>"))
        self.label_4.setText(_translate("MainWindow", "Bbl"))
        self.label_5.setText(_translate("MainWindow", "Liter"))
        self.label_6.setText(_translate("MainWindow", "<html><head/><body><p>M</p></body></html>"))
        self.label_7.setText(_translate("MainWindow", "Ft"))
        self.label_8.setText(_translate("MainWindow", "Inch"))
        self.label_9.setText(_translate("MainWindow", "Unit"))
        self.label_10.setText(_translate("MainWindow", "LENGTH"))
        self.label_11.setText(_translate("MainWindow", "Kg"))
        self.label_12.setText(_translate("MainWindow", "lb"))
        self.label_13.setText(_translate("MainWindow", "gr"))
        self.label_14.setText(_translate("MainWindow", "MASS"))
        self.label_15.setText(_translate("MainWindow", "Unit"))
        self.label_16.setText(_translate("MainWindow", "Acre"))
        self.label_17.setText(_translate("MainWindow", "Unit"))
        self.label_18.setText(_translate("MainWindow", "<html><head/><body><p>Ft<span style=\" vertical-align:super;\">2</span></p></body></html>"))
        self.label_19.setText(_translate("MainWindow", "AREA"))
        self.label_20.setText(_translate("MainWindow", "<html><head/><body><p>M<span style=\" vertical-align:super;\">2</span></p></body></html>"))
        self.label_21.setText(_translate("MainWindow", "<html><head/><body><p>In<span style=\" vertical-align:super;\">2</span></p></body></html>"))
        self.label_22.setText(_translate("MainWindow", "ton"))
        self.label_23.setText(_translate("MainWindow", "Mile"))
        self.label_24.setText(_translate("MainWindow", "Gallon"))
        self.pushButton_5.setText(_translate("MainWindow", "Calc"))
        self.pushButton_20.setText(_translate("MainWindow", "Calc"))
        self.pushButton_25.setText(_translate("MainWindow", "Calc"))
        self.pushButton_26.setText(_translate("MainWindow", "Calc"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.Converter), _translate("MainWindow", "Converter"))
        self.label_25.setText(_translate("MainWindow", "Insert Countdown Timer Here (second) :"))
        self.label_26.setText(_translate("MainWindow", "Second"))
        self.label_27.setText(_translate("MainWindow", "Hello !"))
        self.label_28.setText(_translate("MainWindow", "....."))
        self.pushButton_27.setText(_translate("MainWindow", "START"))
        self.tabWidget.setTabText(self.tabWidget.indexOf(self.Counter), _translate("MainWindow", "Counter"))


def main():
    app = QtWidgets.QApplication(sys.argv)
    MainWindow = QtWidgets.QMainWindow()
    ui = Ui_MainWindow()
    ui.setupUi(MainWindow)
    MainWindow.show()
    app.exec_()

if __name__=='__main__':
    sys.exit(main())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# D:\SOFTWARE\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
print("test")
# Out:
# test
